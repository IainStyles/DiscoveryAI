# %% [markdown]
# #
#
#
# Two scenarios
#
# 1. We know what the groups are we want to find the discriminating features of. Example: data from patients with/without cancer, and we know which is which. In this case we can apply discriminative modelling.
# 2. We don't know what the groups are, or which datapoint lies in which group.

# %% [markdown]
# ## Principal Component Analysis
#
# ### What it does
#
# ### How it does it
#
# ### When to use it

# %% [markdown]
# ## Non-Negative Matrix Factorisation
#
# ### What it does
#
# ### How it does it
#
# ### When to use it

# %% [markdown]
# ## Vector Quantisation (aka "Clustering")
#
# ### What it does
#
# ### How it does it
#
# ### When to use it

# %% [markdown]
# ## Logistic Regression
#
# ### What it does
#
# ### How it does it
#
# ### When to use it

# %% [markdown]
# ## Support Vector Machines
#
# ### What it does
#
# ### How it does it
#
# ### When to use it

# %% [markdown]
# ## Feature Selection
#
# ### What it does
#
# ### How it does it
#
# ### When to use it

# %% [markdown]
# ## Feature Importance: Shapley Additive Explanations
#
# ### What it does
#
# ### How it does it
#
# ### When to use it

# %% [markdown]
# ## Variational Autoencoders
#
# ### What it does
#
# ### How it does it
#
# ### When to use it
